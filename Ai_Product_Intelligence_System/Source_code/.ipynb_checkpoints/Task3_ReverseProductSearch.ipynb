# %%
# Reverse Product Search

## Task 3 – Text-Based Product Search using CLIP

#This notebook demonstrates how to search products using natural language queries.
#The query is converted into an embedding using CLIP and compared with product embeddings using cosine similarity.

# %%
# Uncomment if running for the first time

# !pip install -q transformers torch torchvision pillow scikit-learn pandas numpy

# %%
import numpy as np
import pandas as pd
import torch

from sklearn.metrics.pairwise import cosine_similarity

from transformers import (
    CLIPProcessor,
    CLIPModel,
)

device = "cuda" if torch.cuda.is_available() else "cpu"

print("Device:", device)
# Out:
# cpu

# %%
# Load CLIP model and processor

processor = CLIPProcessor.from_pretrained(
    "openai/clip-vit-base-patch32"
)

model = CLIPModel.from_pretrained(
    "openai/clip-vit-base-patch32"
)

model = model.to(device)
model.eval()

print("Model loaded successfully!")
print(type(model))
# Out:
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Loading weights:   0%|          | 0/398 [00:00<?, ?it/s]
# CLIP Loaded Successfully

# %%
products = [
    {"id":"1","name":"Men's Blue Casual Shirt","category":"Shirts","price":29.99},
    {"id":"2","name":"Blue Checked Shirt","category":"Shirts","price":34.99},
    {"id":"3","name":"Slim Fit Blue Shirt","category":"Shirts","price":39.99},
    {"id":"4","name":"Red Formal Shirt","category":"Shirts","price":44.99},
    {"id":"5","name":"White Casual Shirt","category":"Shirts","price":27.99},
    {"id":"6","name":"Black Denim Jacket","category":"Jackets","price":79.99},
    {"id":"7","name":"Blue Summer Dress","category":"Dresses","price":54.99},
    {"id":"8","name":"Red Casual Pants","category":"Pants","price":49.99},
    {"id":"9","name":"Green Hoodie","category":"Hoodies","price":59.99},
    {"id":"10","name":"Brown Leather Belt","category":"Accessories","price":24.99},
]

products_df = pd.DataFrame(products)
products_df
# Out:
#    id                     name     category  price
# 0   1  Men's Blue Casual Shirt       Shirts  29.99
# 1   2       Blue Checked Shirt       Shirts  34.99
# 2   3      Slim Fit Blue Shirt       Shirts  39.99
# 3   4         Red Formal Shirt       Shirts  44.99
# 4   5       White Casual Shirt       Shirts  27.99
# 5   6       Black Denim Jacket      Jackets  79.99
# 6   7        Blue Summer Dress      Dresses  54.99
# 7   8         Red Casual Pants        Pants  49.99
# 8   9             Green Hoodie      Hoodies  59.99
# 9  10       Brown Leather Belt  Accessories  24.99

# %%
def encode_text(text):
    """
    Encode a text query into a normalized CLIP embedding.
    """

    inputs = processor(
        text=[text],
        return_tensors="pt",
        padding=True,
        truncation=True,
    )

    # Move tensors to GPU/CPU
    inputs = {k: v.to(device) for k, v in inputs.items()}

    with torch.no_grad():
        embedding = model.get_text_features(**inputs)

    # Normalize
    embedding = embedding / embedding.norm(p=2, dim=-1, keepdim=True)

    return embedding.squeeze().cpu().numpy()

# %%
descriptions = {
    "1": "men blue casual shirt",
    "2": "blue checked shirt",
    "3": "slim fit blue shirt",
    "4": "red formal shirt",
    "5": "white casual shirt",
    "6": "black denim jacket",
    "7": "blue summer dress",
    "8": "red casual pants",
    "9": "green hoodie",
    "10": "brown leather belt",
}

image_embeddings = {}
meta = []

for product in products:

    pid = product["id"]

    image_embeddings[pid] = encode_text(descriptions[pid])

    meta.append(product)

print("Embeddings Created:", len(image_embeddings))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[18], line 33
#      29 for product in products:
#      31     pid = str(product["id"])
# ---> 33     image_embeddings[pid] = encode_text(descriptions[pid])
#      35     meta.append(product)
#      37 print("Total Products:",len(image_embeddings))
#
# Cell In[16], line 14, in encode_text(text)
#      10 with torch.no_grad():
#      12     embedding = model.get_text_features(**inputs)
# ---> 14 embedding = embedding / embedding.norm(dim=-1, keepdim=True)
#      16 return embedding.cpu().numpy()[0]
#
# AttributeError: 'BaseModelOutputWithPooling' object has no attribute 'norm'

# %%
def search_products(query, top_k=3):

    query_embedding = encode_text(query)

    product_ids = list(image_embeddings.keys())

    vectors = np.array(
        [image_embeddings[pid] for pid in product_ids]
    )

    similarities = cosine_similarity(
        [query_embedding],
        vectors
    )[0]

    sorted_idx = similarities.argsort()[::-1][:top_k]

    results = []

    for idx in sorted_idx:

        pid = product_ids[idx]

        product = next(
            p for p in meta if p["id"] == pid
        )

        results.append({
            "id": pid,
            "name": product["name"],
            "category": product["category"],
            "price": product["price"],
            "score": float(similarities[idx])
        })

    return results

# %%
def display_results(query, results):

    print("=" * 60)
    print("Search Query:", query)
    print("=" * 60)

    for i, item in enumerate(results, start=1):

        print(f"\nRank {i}")
        print("Product :", item["name"])
        print("Category:", item["category"])
        print("Price   : $", item["price"])
        print("Score   :", round(item["score"], 4))

# %%
query = "blue casual shirt"

results = search_products(query)

display_results(query, results)

results
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[21], line 3
#       1 query = "blue casual shirt"
# ----> 3 results = search_products(query)
#       5 display_results(query,results)
#       7 results
#
# Cell In[19], line 3, in search_products(query, top_k)
#       1 def search_products(query,top_k=3):
# ----> 3     query_embedding = encode_text(query)
#       5     ids = list(image_embeddings.keys())
#       7     vectors = np.array(
#       8         [image_embeddings[i] for i in ids]
#       9     )
#
# Cell In[16], line 14, in encode_text(text)
#      10 with torch.no_grad():
#      12     embedding = model.get_text_features(**inputs)
# ---> 14 embedding = embedding / embedding.norm(dim=-1, keepdim=True)
#      16 return embedding.cpu().numpy()[0]
#
# AttributeError: 'BaseModelOutputWithPooling' object has no attribute 'norm'

# %%
while True:

    query = input("Enter product description (or quit): ")

    if query.lower()=="quit":
        break

    results = search_products(query)

    display_results(query,results)

# %%
# Out:
# Enter query (or 'quit'):  blue casual shirt
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 run_search()
#
# Cell In[10], line 6, in run_search()
#       4 if q.lower() == "quit":
#       5     break
# ----> 6 res = search_products(q, top_k=3)
#       7 display_results(q, res)
#
# Cell In[8], line 2, in search_products(query, top_k)
#       1 def search_products(query, top_k=3):
# ----> 2     q = encode_text(query)
#       3     product_ids = list(image_embeddings.keys())
#       4     emb = np.array([image_embeddings[i] for i in product_ids])
#
# Cell In[4], line 2, in encode_text(text)
#       1 def encode_text(text):
# ----> 2     tokens = clip.tokenize([text]).to(device)
#       3     with torch.no_grad():
#       4         feat = model.encode_text(tokens)
#
# AttributeError: 'NoneType' object has no attribute 'tokenize'
